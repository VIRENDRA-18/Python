# %%
import pandas as pd

# %%
data = ({'a' : [1,2,3,4,],
         'b' : [5,6,7,8],
         'c' : ['sudg', 'krish', 'hitesh', "navin"]})

# %%
pd.DataFrame(data)
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df.set_index('a')
# Out:
#    b       c
# a
# 1  5    sudg
# 2  6   krish
# 3  7  hitesh
# 4  8   navin

# %%
df
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df.set_index('a', inplace = True)

# %%
df
# Out:
#    b       c
# a
# 1  5    sudg
# 2  6   krish
# 3  7  hitesh
# 4  8   navin

# %%
# ise data ko reset krna ho to

df.reset_index()
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df
# Out:
#    b       c
# a
# 1  5    sudg
# 2  6   krish
# 3  7  hitesh
# 4  8   navin

# %%
df = df.reset_index()

# %%
df
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
data = ({'a' : [1,2,3,4,],
         'b' : [5,6,7,8],
         'c' : ['sudh', 'krish', 'hitesh', "navin"]})
df1 = pd.DataFrame(data, index=['a', 'b','c','d'])

# %%
df1
# Out:
#    a  b       c
# a  1  5    sudh
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin

# %%
# reindixing kerna hai = inka arragement change kr diya

# %%
df1 = df1.reindex(['b','c','d','a'])

# %%
df1
# Out:
#    a  b       c
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin
# a  1  5    sudh

# %%
df1.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000023B1F4C0E10>

# %%
for i in df1.iterrows():
    print(i)   # rowwise data  de dega
# Out:
# ('b', a        2
# b        6
# c    krish
# Name: b, dtype: object)
# ('c', a         3
# b         7
# c    hitesh
# Name: c, dtype: object)
# ('d', a        4
# b        8
# c    navin
# Name: d, dtype: object)
# ('a', a       1
# b       5
# c    sudh
# Name: a, dtype: object)

# %%
for i,j in df1.iterrows():
    print(i,j)
# Out:
# b a        2
# b        6
# c    krish
# Name: b, dtype: object
# c a         3
# b         7
# c    hitesh
# Name: c, dtype: object
# d a        4
# b        8
# c    navin
# Name: d, dtype: object
# a a       1
# b       5
# c    sudh
# Name: a, dtype: object

# %%
for i in df1.items():
    print(i)   # columns wise data de rha hai
# Out:
# ('a', b    2
# c    3
# d    4
# a    1
# Name: a, dtype: int64)
# ('b', b    6
# c    7
# d    8
# a    5
# Name: b, dtype: int64)
# ('c', b     krish
# c    hitesh
# d     navin
# a      sudh
# Name: c, dtype: object)

# %%
df1
# Out:
#    a  b       c
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin
# a  1  5    sudh

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
[i for i in df['b']]
# Out:
# [5, 6, 7, 8]

# %%
df1
# Out:
#    a  b       c
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin
# a  1  5    sudh

# %%
# ab muje ager sum krna hai

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# a                      10
# b                      26
# c    krishhiteshnavinsudh
# dtype: object

# %%
df2 = df1[['a','b']]

# %%
df2
# Out:
#    a  b
# b  2  6
# c  3  7
# d  4  8
# a  1  5

# %%
df2.applymap(lambda x : x**2)
# Out:
# C:\Users\viren\AppData\Local\Temp\ipykernel_4744\4004635628.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.applymap(lambda x : x**2)
#     a   b
# b   4  36
# c   9  49
# d  16  64
# a   1  25

# %%
df1
# Out:
#    a  b       c
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin
# a  1  5    sudh

# %%
df1.reset_index()
# Out:
#   index  a  b       c
# 0     b  2  6   krish
# 1     c  3  7  hitesh
# 2     d  4  8   navin
# 3     a  1  5    sudh

# %%
df1
# Out:
#    a  b       c
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin
# a  1  5    sudh

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  7  hitesh
# 1  2  6   krish
# 3  4  8   navin
# 0  1  5    sudg

# %%
df.sort_index(ascending = False)
# Out:
#    a  b       c
# 3  4  8   navin
# 2  3  7  hitesh
# 1  2  6   krish
# 0  1  5    sudg

# %%
pd.set_option("display.max_colwidth" ,1000)
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language."] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.

# %%
pd.set_option("display.max_colwidth" ,1000)
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language." , "my name is sudh" ,"i use to teach data science "] })

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i use to teach data science

# %%
df3['len'] = df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i use to teach data science
#
#    len
# 0  765
# 1   15
# 2   28

# %%
# muje character nhi word chaiye

t = "i use to teach data science"
t.split()
len(t.split())
# Out:
# 6

# %%
df3['word_count' ] = df3['Desc'].apply(lambda x : len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i use to teach data science
#
#    len  word_count
# 0  765         104
# 1   15           4
# 2   28           6

# %%
df
# Out:
#    a  b       c
# 0  1  5    sudg
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df['a'].mean()
# Out:
# np.float64(2.5)

# %%
df['a'].sum()
# Out:
# np.int64(10)

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# 1.2909944487358056

# %%
# Python Pandas Window Function

df4 = pd.DataFrame({'a' : [3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window = 2)
# Out:
# Rolling [window=2,center=False,axis=0,method=single]

# %%
df4['a'].rolling(window = 1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window = 2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window = 3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df4['a'].rolling(window = 3).sum()
# Out:
# 0     NaN
# 1     NaN
# 2    12.0
# 3    11.0
# 4     8.0
# 5     6.0
# 6     8.0
# 7    12.0
# 8    15.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window = 3).min()
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    2.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    3.0
# 8    4.0
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window = 2).max()
# Out:
# 0    NaN
# 1    4.0
# 2    5.0
# 3    5.0
# 4    2.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %% [markdown]
# Python Pandas Date Functionality

# %%
# Python Pandas Date Functionality

date = pd.date_range(start = '2026-01-01', end = '2026-01-20')

# %%
date
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06', '2026-01-07', '2026-01-08',
#                '2026-01-09', '2026-01-10', '2026-01-11', '2026-01-12',
#                '2026-01-13', '2026-01-14', '2026-01-15', '2026-01-16',
#                '2026-01-17', '2026-01-18', '2026-01-19', '2026-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date = pd.DataFrame({'date' : date})

# %%
df_date
# Out:
#          date
# 0  2026-01-01
# 1  2026-01-02
# 2  2026-01-03
# 3  2026-01-04
# 4  2026-01-05
# 5  2026-01-06
# 6  2026-01-07
# 7  2026-01-08
# 8  2026-01-09
# 9  2026-01-10
# 10 2026-01-11
# 11 2026-01-12
# 12 2026-01-13
# 13 2026-01-14
# 14 2026-01-15
# 15 2026-01-16
# 16 2026-01-17
# 17 2026-01-18
# 18 2026-01-19
# 19 2026-01-20

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df7 = pd.DataFrame({"date" : ['2023-06-23' , '2023-06-22','2023-06-20']})

# %%
df7
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-20

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['update_date'] = pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date update_date
# 0  2023-06-23  2023-06-23
# 1  2023-06-22  2023-06-22
# 2  2023-06-20  2023-06-20

# %%
df7.dtypes
# Out:
# date                   object
# update_date    datetime64[ns]
# dtype: object

# %%
df7['year'] = df7['update_date'].dt.year

# %%
df7
# Out:
#          date update_date  year
# 0  2023-06-23  2023-06-23     6
# 1  2023-06-22  2023-06-22     6
# 2  2023-06-20  2023-06-20     6

# %%
df7['month'] = df7['update_date'].dt.month

# %%
df7
# Out:
#          date update_date  year  month
# 0  2023-06-23  2023-06-23  2023      6
# 1  2023-06-22  2023-06-22  2023      6
# 2  2023-06-20  2023-06-20  2023      6

# %%
df7['day'] = df7['update_date'].dt.day

# %%
df7
# Out:
#          date update_date  year  month  day
# 0  2023-06-23  2023-06-23  2023      6   23
# 1  2023-06-22  2023-06-22  2023      6   22
# 2  2023-06-20  2023-06-20  2023      6   20

# %% [markdown]
# Python Pandas Time Delta

# %%
pd.Timedelta(days = 1, hours = 5, minutes = 45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2026-01-20')

# %%
td = pd.Timedelta(days=1)

# %%
dt + td
# Out:
# Timestamp('2026-01-21 00:00:00')

# %% [markdown]
# Python Pandas - Categorical Data

# %%
#Python Pandas - Categorical Data

data = ["sudh" , "krish" , "hitesh" , "navin","sudh" ,"sudh" ]

# %%
data
# Out:
# ['sudh', 'krish', 'hitesh', 'navin', 'sudh', 'sudh']

# %%
pd.Categorical(data)
# Out:
# ['sudh', 'krish', 'hitesh', 'navin', 'sudh', 'sudh']
# Categories (4, object): ['hitesh', 'krish', 'navin', 'sudh']

# %%
cat = pd.Categorical(data)

# %%
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'navin', 'sudh', 'sudh']
# Categories (4, object): ['hitesh', 'krish', 'navin', 'sudh']

# %%
cat.value_counts()
# Out:
# hitesh    1
# krish     1
# navin     1
# sudh      3
# Name: count, dtype: int64

# %% [markdown]
# #Python Pandas – Visualization

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,6,7,8]})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot(x= 'a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x= 'a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
d = pd.Series([1,2,3,3,5,6,6,8])
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot.pie()
# Out:
# <Axes: >
