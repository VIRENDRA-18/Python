# %% [markdown]
# Encapsulation = data protect and hide krne ka kaam krta hai

# %%
class car :
    def __init__(self, year, make, model, speed):

        self.__year = year
        self.__make = make
        self.__model = model
        self.__speed = 0

    def set_speed(self,speed) :
        self.__speed = 0 if speed < 0 else speed

    def get_speed (self)    :
        return self.__speed

# %%
c = car(2021, "toyata", "innova", 12 )

# %%
c.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 c.year
#
# AttributeError: 'car' object has no attribute 'year'

# %%
c.__year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 c.__year
#
# AttributeError: 'car' object has no attribute '__year'

# %%
c._car__year
# Out:
# 2021

# %%
c.set_speed(-68)

# %%
c.get_speed()
# Out:
# 0

# %%
c.set_speed(78)

# %%
c.get_speed()
# Out:
# 78

# %%
class bank_account :
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount) :
        self.__balance = self.__balance + amount  

    def withdraw(self, amount) :
        if self.__balance >= amount:
            self.__balance = self.__balance - amount
            return True
        else :
            return False   

    def get_balance(self)  :
        return self.__balance

# %%
virendra = bank_account(1000)

# %%
virendra.get_balance()
# Out:
# 1000

# %%
virendra.deposit(5000)

# %%
virendra.get_balance()
# Out:
# 6000

# %%
virendra.get_balance()
# Out:
# 6000

# %%
virendra.deposit(200)

# %%
virendra.get_balance()
# Out:
# 6200

# %%
virendra.withdraw(1200)
# Out:
# True

# %%
virendra.get_balance()
# Out:
# 5000

# %%
virendra.withdraw(82000)
# Out:
# False

# %%
virendra.get_balance()
# Out:
# 5000

# %% [markdown]
# Practice

# %%
class test :
    def __init__(self,a, b):
        self.a = a
        self.b = b

# %%
t = test(23,45)

# %%
t.a = 84793284

# %%
t.a
# Out:
# 84793284

# %%
class car :
    def __init__(self, year, make, model, speed):
        self.__year = year
        self.__make = make
        self.__model = model
        self.__speed = 0

# %%
class car :
    def __init__(self, year, make, model, speed):
        self.__year = year
        self.__make = make
        self.__model = model
        self.__speed = 0

    def set_speed(self,speed):  
        self.__speed = 0 if speed < 0 else speed  

    def get_speed(self):
        return self.__speed

# %%
c = car(2004, 'toyata', 'innova', 12)

# %%
c.set_speed(-7676)

# %%
c.get_speed()
# Out:
# 0

# %%
c.set_speed(78)

# %%
c.get_speed()
# Out:
# 0

# %%
class bank_account :
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self , amount) :
        self.__balance = self.__balance + amount  

    def withdrow(self,amount) :
        if self.__balance >= amount :
            self.__balance = self.__balance - amount
            return True
        else :
            return False
        
        
    def get_balance(self):
        return self.__balance

# %%
virendra = bank_account(5000)

# %%
virendra.get_balance()
# Out:
# 5000

# %%
virendra.deposit(4000)

# %%
virendra.get_balance(
    
)
# Out:
# 9000

# %%
virendra.withdrow(3550)
# Out:
# True

# %%
virendra.get_balance()
# Out:
# 5450
