# %%
import abc
class pwskills : 

    @abc.abstractmethod
    def students_details(self) :
        pass
    
    @abc.abstractmethod
    def students_assignments(self) :
        pass

    @abc.abstractmethod
    def students_marks(self) :
        pass

# %%
class students_details :

    def students_details(self) :
        return "this is a method to taking student details"
    
    def students_assignments(self) :
        return "this is a method fro assign details fro a particular students"

# %%
class data_science_master :

    def students_details(self) :
        return "this is a method to taking student details fro data science masters"
    
    def students_assignments(self) :
        return "this is a method fro assign details fro a particular students for data science masters" \

# %%
dsm = data_science_master()

# %%
dsm.students_details()
# Out:
# 'this is a method to taking student details fro data science masters'

# %%
dsm.students_assignments()
# Out:
# 'this is a method fro assign details fro a particular students for data science masters'

# %%
sd = students_details()

# %%
sd.students_details()
# Out:
# 'this is a method to taking student details'

# %%
sd.students_assignments()
# Out:
# 'this is a method fro assign details fro a particular students'

# %% [markdown]
# PRACTICE

# %%
# Abstraction --> use blueprint ya skleart ke liye
