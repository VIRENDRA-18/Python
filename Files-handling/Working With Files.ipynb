# %%
f = open('test.txt', 'w')

# %%
pwd
# Out:
# 'c:\\Users\\viren\\Desktop\\Python\\Files-handling'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 82E2-7C2E
#
#  Directory of c:\Users\viren\Desktop\Python\Files-handling
#
# 27-01-2026  00:38    <DIR>          .
# 27-01-2026  00:22    <DIR>          ..
# 27-01-2026  00:38                 0 test.txt
# 27-01-2026  00:23               255 Working With Files.ipynb
#                2 File(s)            255 bytes
#                2 Dir(s)  146,530,689,024 bytes free

# %%
f.write('this is my first file create and learn about file handling')
# Out:
# 58

# %%
f.close()

# %%
f = open('test.txt', 'w')

# %%
f.write('Hello everyone my name is virendra singh')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 f.write('Hello everyone my name is virendra singh')
#
# ValueError: I/O operation on closed file.

# %%
f = open('test.txt', 'w')

# %%
f.write('Hello everyone my name is virendra singh')
# Out:
# 40

# %%
f.close()

# %%
f = open('test.txt', 'a')

# %%
f.write(' I love data science')
# Out:
# 20

# %%
f.close()

# %%
f = open('test.txt', 'a')

# %%
f.write('Databricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture ' \
'to create the next generation of data and AI powered companies. A Databricks partner since 2020, Celebal Technologies has been honoured with the 2023 Databricks Partner Awards, receiving two prestigious recognitions: the Databricks APJ Partner of the Year Award for the second consecutive year, and the Databricks Migrations Partner of the Year – APJ Award.  ' )
# Out:
# 579

# %%
f.close()

# %%
data = f = open('test.txt', 'r')

# %%
data.readline()
# Out:
# ''

# %%
data.seek(0)
# Out:
# 0

# %%
data.readline()
# Out:
# 'Hello everyone my name is virendra singhI love data science I love data scienceDatabricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies.Databricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies. A Databricks partner since 2020, Celebal Technologies has been honoured with the 2023 Databricks Partner Awards, receiving two prestigious recognitions: the Databricks APJ Partner of the Year Award for the second consecutive year, and the Databricks Migrations Partner of the Year – APJ Award.  Databricks ventures invest in innovative companies that 
# ...

# %%
data.read()
# Out:
# ''

# %%
data.seek(0)
# Out:
# 0

# %%
data.read()
# Out:
# 'Hello everyone my name is virendra singhI love data science I love data scienceDatabricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies.Databricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies. A Databricks partner since 2020, Celebal Technologies has been honoured with the 2023 Databricks Partner Awards, receiving two prestigious recognitions: the Databricks APJ Partner of the Year Award for the second consecutive year, and the Databricks Migrations Partner of the Year – APJ Award.  Databricks ventures invest in innovative companies that 
# ...

# %%
data1 = f = open('test.txt', 'r')

# %%
for i in data1 :
    print(i)
# Out:
# Hello everyone my name is virendra singhI love data science I love data scienceDatabricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies.Databricks ventures invest in innovative companies that share a similar view of the future for data, analytics and AI. Their Lakehouse fund is focused on early and growth–stage companies using the Lakehouse architecture to create the next generation of data and AI powered companies. A Databricks partner since 2020, Celebal Technologies has been honoured with the 2023 Databricks Partner Awards, receiving two prestigious recognitions: the Databricks APJ Partner of the Year Award for the second consecutive year, and the Databricks Migrations Partner of the Year – APJ Award.  Databricks ventures invest in innovative companies that s
# ...

# %%
import os

# %%
os.path.getsize('test.txt')
# Out:
# 1530

# %%
f = open('test1.txt', 'w')

# %%
f.write('Hii i am virendra singh .')
# Out:
# 25

# %%
f.close()

# %%
os.rename('test1.txt','new.txt')

# %%
os.remove('new.txt')

# %%
f = open('test2.txt', 'w')

# %%
f.write('good morning guys, welcome to the earth ')
# Out:
# 40

# %%
f.close()

# %%
import shutil

# %%
shutil.copy('test2.txt','copy_new.txt')
# Out:
# 'copy_new.txt'

# %%
with open('copy_new.txt','r') as f :
    print(f.read())
# Out:
# good morning guys, welcome to the earth
