# %%
# Inheritance

class test :

    def test_meth(self):
        return "this is my first class"

# %%
class child_test(test):
    pass

# %%
child_test_obj = child_test()

# %%
child_test_obj.test_meth()
# Out:
# 'this is my first class'

# %%
class class1 :

    def test_class1(self):
        return "this is my class1"

# %%
class class2(class1):

    def test_class2(self):
        return "this is my class2"

# %%
class class3(class2):

    def test_class3(self):
        pass

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# 'this is my class1'

# %%
obj_class3.test_class2()
# Out:
# 'this is my class2'

# %%
obj_class3.test_class3()

# %%
# multipal

class class1 :

    def test_class1(self):
        return "this is class1"

# %%
class class12 :

    def test_class2(self):
        return "this is class2"

# %%
class class3 (class1, class2) :

    pass

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# 'this is class1'

# %% [markdown]
# PRACTICE

# %%
class viru :
    def test_viru(self) :
        return "Viru your marks is 78. you are pass is ML"

# %%
class praveen :
    def test_praveen(self):
        return "praveen your marks is 67. you are pass in Cyber"

# %%
class anisha :
    def test_anisha(self) :
        return "anisha your marks is 82. you are pass in chemistry"

# %%
class result(viru,praveen,anisha) :
    pass

# %%
class_result = result()

# %%
class_result.test_praveen()
# Out:
# 'praveen your marks is 67. you are pass in Cyber'

# %%
class_result.test_anisha()
# Out:
# 'anisha your marks is 82. you are pass in chemistry'
