# %%
dict = {}
print(dict)
# Out:
# {}

# %%
type(dict)
# Out:
# dict

# %%
len(dict)
# Out:
# 0

# %%
dict1 = {"key" : "value"}
print(dict1)
# key is always unique
# Out:
# {'key': 'value'}

# %%
dict2 = {"Name" : "Virendra", "Age" : 22, "Role" : "Python Developer", "Emial" : "viru0125@gmail.com"}
print(dict2)
# Out:
# {'Name': 'Virendra', 'Age': 22, 'Role': 'Python Developer', 'Emial': 'viru0125@gmail.com'}

# %%
dict2[2]
# indexing di mene but it is not work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict2[2]
#
# KeyError: 2

# %%
dict2["Name"]
# it take the key not index
# Out:
# 'Virendra'

# %%
dict2["Emial"]
# Out:
# 'viru0125@gmail.com'

# %%
dict3 = {"Name" : "mudit", "Age" : 24, "Name" : "Kavita", True : 25 }
print(dict3)
# Out:
# {'Name': 'Kavita', 'Age': 24, True: 25}

# %%
dict3['Name']
#yaha pe kavita name is liye aaya because yaha pe key unique nhi hai name ki is veje se new value ke saat overringht kr geiii , so take the key always unique
# Out:
# 'Kavita'

# %%
dict3[1]
# Out:
# 25
