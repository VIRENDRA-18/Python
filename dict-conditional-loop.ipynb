# %%
dict = {}
print(dict)
# Out:
# {}

# %%
type(dict)
# Out:
# dict

# %%
len(dict)
# Out:
# 0

# %%
dict1 = {"key" : "value"}
print(dict1)
# key is always unique
# Out:
# {'key': 'value'}

# %%
dict2 = {"Name" : "Virendra", "Age" : 22, "Role" : "Python Developer", "Emial" : "viru0125@gmail.com"}
print(dict2)
# Out:
# {'Name': 'Virendra', 'Age': 22, 'Role': 'Python Developer', 'Emial': 'viru0125@gmail.com'}

# %%
dict2[2]
# indexing di mene but it is not work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict2[2]
#
# KeyError: 2

# %%
dict2["Name"]
# it take the key not index
# Out:
# 'Virendra'

# %%
dict2["Emial"]
# Out:
# 'viru0125@gmail.com'

# %%
dict3 = {"Name" : "mudit", "Age" : 24, "Name" : "Kavita", True : 25 }
print(dict3)
# Out:
# {'Name': 'Kavita', 'Age': 24, True: 25}

# %%
dict3['Name']
#yaha pe kavita name is liye aaya because yaha pe key unique nhi hai name ki is veje se new value ke saat overringht kr geiii , so take the key always unique
# Out:
# 'Kavita'

# %%
dict3[1]
# Out:
# 25

# %%
dict4 = {"Company" : "celebal", "Job Role" : ['React developer', "Node.js developer", 'Data Science Engineer', 'Cyber Security']}
print(dict4)
# Out:
# {'Company': 'celebal', 'Job Role': ['React developer', 'Node.js developer', 'Data Science Engineer', 'Cyber Security']}

# %%
dict4['Company']
# Out:
# 'celebal'

# %%
dict4['Job Role']
# Out:
# ['React developer',
#  'Node.js developer',
#  'Data Science Engineer',
#  'Cyber Security']

# %%
dict4['Job Role'][2]
# Out:
# 'Data Science Engineer'

# %%
dict4['Job Role'][3]
# Out:
# 'Cyber Security'

# %%
dict4['Job Role'][4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 dict4['Job Role'][4]
#
# IndexError: list index out of range

# %%
dict5 = {"Name" : ["Viru", "Mudit", "Anisha", "Meena"], "Number" : (1,2,3,4), "Interview_Date" : {12,13,15,17}, "Job_Role" : ['React developer', "Node.js developer", 'Data Science Engineer', 'Cyber Security'], "Interview_Time" : {'React developer' : 8, "Node.js developer" : 10, 'Data Science Engineer' : 12, 'Cyber Security' : 2}}
print(dict5)
# Out:
# {'Name': ['Viru', 'Mudit', 'Anisha', 'Meena'], 'Number': (1, 2, 3, 4), 'Interview_Date': {17, 12, 13, 15}, 'Job_Role': ['React developer', 'Node.js developer', 'Data Science Engineer', 'Cyber Security'], 'Interview_Time': {'React developer': 8, 'Node.js developer': 10, 'Data Science Engineer': 12, 'Cyber Security': 2}}

# %%
dict5
# Out:
# {'Name': ['Viru', 'Mudit', 'Anisha', 'Meena'],
#  'Number': (1, 2, 3, 4),
#  'Interview_Date': {12, 13, 15, 17},
#  'Job_Role': ['React developer',
#   'Node.js developer',
#   'Data Science Engineer',
#   'Cyber Security'],
#  'Interview_Time': {'React developer': 8,
#   'Node.js developer': 10,
#   'Data Science Engineer': 12,
#   'Cyber Security': 2}}

# %%
dict5['Interview_Time']['Data Science Engineer']
# Out:
# 12

# %%
dict5['Mentor'] = ["Ram", "Priyanshi Jain", 'Akash']

# %%
dict5
# Out:
# {'Name': ['Viru', 'Mudit', 'Anisha', 'Meena'],
#  'Number': (1, 2, 3, 4),
#  'Interview_Date': {12, 13, 15, 17},
#  'Job_Role': ['React developer',
#   'Node.js developer',
#   'Data Science Engineer',
#   'Cyber Security'],
#  'Interview_Time': {'React developer': 8,
#   'Node.js developer': 10,
#   'Data Science Engineer': 12,
#   'Cyber Security': 2},
#  'Mentor': ['Ram', 'Priyanshi Jain', 'Akash']}

# %%
del dict5['Number']

# %%
dict5
# Out:
# {'Name': ['Viru', 'Mudit', 'Anisha', 'Meena'],
#  'Interview_Date': {12, 13, 15, 17},
#  'Job_Role': ['React developer',
#   'Node.js developer',
#   'Data Science Engineer',
#   'Cyber Security'],
#  'Interview_Time': {'React developer': 8,
#   'Node.js developer': 10,
#   'Data Science Engineer': 12,
#   'Cyber Security': 2},
#  'Mentor': ['Ram', 'Priyanshi Jain', 'Akash']}

# %%
dict5.keys()
# Out:
# dict_keys(['Name', 'Interview_Date', 'Job_Role', 'Interview_Time', 'Mentor'])

# %%
#list ke form mai chaiye ache se 
list(dict5.keys())
# Out:
# ['Name', 'Interview_Date', 'Job_Role', 'Interview_Time', 'Mentor']

# %%
dict5.items()
# Out:
# dict_items([('Name', ['Viru', 'Mudit', 'Anisha', 'Meena']), ('Interview_Date', {17, 12, 13, 15}), ('Job_Role', ['React developer', 'Node.js developer', 'Data Science Engineer', 'Cyber Security']), ('Interview_Time', {'React developer': 8, 'Node.js developer': 10, 'Data Science Engineer': 12, 'Cyber Security': 2}), ('Mentor', ['Ram', 'Priyanshi Jain', 'Akash'])])

# %%
list(dict5.items())
# Out:
# [('Name', ['Viru', 'Mudit', 'Anisha', 'Meena']),
#  ('Interview_Date', {12, 13, 15, 17}),
#  ('Job_Role',
#   ['React developer',
#    'Node.js developer',
#    'Data Science Engineer',
#    'Cyber Security']),
#  ('Interview_Time',
#   {'React developer': 8,
#    'Node.js developer': 10,
#    'Data Science Engineer': 12,
#    'Cyber Security': 2}),
#  ('Mentor', ['Ram', 'Priyanshi Jain', 'Akash'])]

# %%
dict5.values()
# Out:
# dict_values([['Viru', 'Mudit', 'Anisha', 'Meena'], {17, 12, 13, 15}, ['React developer', 'Node.js developer', 'Data Science Engineer', 'Cyber Security'], {'React developer': 8, 'Node.js developer': 10, 'Data Science Engineer': 12, 'Cyber Security': 2}, ['Ram', 'Priyanshi Jain', 'Akash']])

# %%
list(dict5.values())
# Out:
# [['Viru', 'Mudit', 'Anisha', 'Meena'],
#  {12, 13, 15, 17},
#  ['React developer',
#   'Node.js developer',
#   'Data Science Engineer',
#   'Cyber Security'],
#  {'React developer': 8,
#   'Node.js developer': 10,
#   'Data Science Engineer': 12,
#   'Cyber Security': 2},
#  ['Ram', 'Priyanshi Jain', 'Akash']]

# %%
dict5.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 dict5.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
dict5.pop('Mentor')
# Out:
# ['Ram', 'Priyanshi Jain', 'Akash']

# %%
dict5
# Out:
# {'Name': ['Viru', 'Mudit', 'Anisha', 'Meena'],
#  'Interview_Date': {12, 13, 15, 17},
#  'Job_Role': ['React developer',
#   'Node.js developer',
#   'Data Science Engineer',
#   'Cyber Security'],
#  'Interview_Time': {'React developer': 8,
#   'Node.js developer': 10,
#   'Data Science Engineer': 12,
#   'Cyber Security': 2}}

# %%
l = [1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in l :
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in l :
    print(i+1)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
l1 = []
for i in l :
    print(i+1)
    l1.append(i+1)
l1
# Out:
# 2
# 3
# 4
# 5
# 6
# [2, 3, 4, 5, 6]

# %%
list = ["viru", "ram", "piyush", "praveen"]
print(list)
# Out:
# ['viru', 'ram', 'piyush', 'praveen']

# %%
for i in list :
    print(i)
# Out:
# viru
# ram
# piyush
# praveen

# %%
str(list).upper()
# Out:
# "['VIRU', 'RAM', 'PIYUSH', 'PRAVEEN']"

# %%
list
# Out:
# ['viru', 'ram', 'piyush', 'praveen']

# %%
list
# Out:
# ['viru', 'ram', 'piyush', 'praveen']

# %%
list1 = []
for i in list :
    print(i.upper())
    list1.append(i.upper())
list1
# Out:
# VIRU
# RAM
# PIYUSH
# PRAVEEN
# ['VIRU', 'RAM', 'PIYUSH', 'PRAVEEN']

# %%
list = [2,3,5,4,"Viru", "Anisha", 45.78, 22.4, "Kumkum"]
print(list)
# Out:
# [2, 3, 5, 4, 'Viru', 'Anisha', 45.78, 22.4, 'Kumkum']

# %%
list_num = []
list_str = []
for i in list : 
    if type(i) == int or type(i) == float :
        list_num.append(i)
    else :
        list_str.append(i)

# %%
list_num
# Out:
# [2, 3, 5, 4, 45.78, 22.4]

# %%
list_str
# Out:
# ['Viru', 'Anisha', 'Kumkum']
