# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv("services.csv")
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df = pd.read_csv("services.csv")

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df["eligibility"]
# Out:
# 0     Age 55 or over for most programs, age 60 or ov...
# 1     Age 55 or over, county resident and willing an...
# 2           Resident of San Mateo County age 55 or over
# 3                                                   NaN
# 4     Eligibility: Low-income family with legal cust...
# 5                                                   NaN
# 6                                        Age 18 or over
# 7               Homebound person unable to cook or shop
# 8       Resident of California to obtain a library card
# 9               Resident of California to obtain a card
# 10    Resident of California to obtain a library car...
# 11    English-speaking adult reading at or below 7th...
# 12      Resident of California to obtain a library card
# 13    None for most services. For emergency assistan...
# 14    Age 21-60, detoxed, physically able and willin...
# 15                        None for emergency assistance
# 16                                  Low-income families
# ...

# %%
pd.DataFrame(df["eligibility"])
# Out:
#                                           eligibility
# 0   Age 55 or over for most programs, age 60 or ov...
# 1   Age 55 or over, county resident and willing an...
# 2         Resident of San Mateo County age 55 or over
# 3                                                 NaN
# 4   Eligibility: Low-income family with legal cust...
# 5                                                 NaN
# 6                                      Age 18 or over
# 7             Homebound person unable to cook or shop
# 8     Resident of California to obtain a library card
# 9             Resident of California to obtain a card
# 10  Resident of California to obtain a library car...
# 11  English-speaking adult reading at or below 7th...
# 12    Resident of California to obtain a library card
# 13  None for most services. For emergency assistan...
# 14  Age 21-60, detoxed, physically able and willin...
# 15                      None for emergency assistance
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 23

# %%
type(df["eligibility"])
# Out:
# pandas.core.series.Series

# %%
df["eligibility"]
# Out:
# 0     Age 55 or over for most programs, age 60 or ov...
# 1     Age 55 or over, county resident and willing an...
# 2           Resident of San Mateo County age 55 or over
# 3                                                   NaN
# 4     Eligibility: Low-income family with legal cust...
# 5                                                   NaN
# 6                                        Age 18 or over
# 7               Homebound person unable to cook or shop
# 8       Resident of California to obtain a library card
# 9               Resident of California to obtain a card
# 10    Resident of California to obtain a library car...
# 11    English-speaking adult reading at or below 7th...
# 12      Resident of California to obtain a library card
# 13    None for most services. For emergency assistan...
# 14    Age 21-60, detoxed, physically able and willin...
# 15                        None for emergency assistance
# 16                                  Low-income families
# ...

# %%
import pandas as pd 

StudentData = {
    'Id' : [101,102,103,104,105,106,107,108,109],
    'Name' : ["Virendra", "Mudit", "Praveen", "Anisha", "Kumkum", "Ravi", "Meena", "Nisha","Rahul"],
    'Branch' : ["Computer Science", "Data Science", "Design", "Nurshing","Nurshing","Computer Science","Cyber Security","Design","Machine Learning" ],
    'Age' : [22,21,23,20,21,25,19,26,28],
    'Gender' : ["Male","Male","Male","Female","Female","Male","Female","Female","Male"],
    'Email' : ["Viru@gmail.com","mudit@gmail.com","praveen@gmail.com","anisha@gmail.com","kumkum@gmail.com","ravi@gmail.com","meena@gmail.com","nisha@gmail.com","rahul@gmail.com",] 
}

df = pd.DataFrame(StudentData, index = ['A','B','C','D','E','F','G','H','G'] )
df
# Out:
#     Id      Name            Branch  Age  Gender              Email
# A  101  Virendra  Computer Science   22    Male     Viru@gmail.com
# B  102     Mudit      Data Science   21    Male    mudit@gmail.com
# C  103   Praveen            Design   23    Male  praveen@gmail.com
# D  104    Anisha          Nurshing   20  Female   anisha@gmail.com
# E  105    Kumkum          Nurshing   21  Female   kumkum@gmail.com
# F  106      Ravi  Computer Science   25    Male     ravi@gmail.com
# G  107     Meena    Cyber Security   19  Female    meena@gmail.com
# H  108     Nisha            Design   26  Female    nisha@gmail.com
# G  109     Rahul  Machine Learning   28    Male    rahul@gmail.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create Series 

Age = [12,34,56,22,32]

df1 = pd.Series(Age,index=[111,122,133,144,155])

df1
# Out:
# 111    12
# 122    34
# 133    56
# 144    22
# 155    32
# dtype: int64

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
len(df1)
# Out:
# 5

# %%
df1[111]
# Out:
# np.int64(12)

# %%
df
# Out:
#     Id      Name            Branch  Age  Gender              Email
# A  101  Virendra  Computer Science   22    Male     Viru@gmail.com
# B  102     Mudit      Data Science   21    Male    mudit@gmail.com
# C  103   Praveen            Design   23    Male  praveen@gmail.com
# D  104    Anisha          Nurshing   20  Female   anisha@gmail.com
# E  105    Kumkum          Nurshing   21  Female   kumkum@gmail.com
# F  106      Ravi  Computer Science   25    Male     ravi@gmail.com
# G  107     Meena    Cyber Security   19  Female    meena@gmail.com
# H  108     Nisha            Design   26  Female    nisha@gmail.com
# G  109     Rahul  Machine Learning   28    Male    rahul@gmail.com

# %%
pd.DataFrame(df['Name'])
# Out:
#        Name
# A  Virendra
# B     Mudit
# C   Praveen
# D    Anisha
# E    Kumkum
# F      Ravi
# G     Meena
# H     Nisha
# G     Rahul

# %%
type(pd.DataFrame(df['Name']))
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name','Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\viren\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['Name','Age']
#
# ...

# %%
df[['Name','Age']]
# Out:
#        Name  Age
# A  Virendra   22
# B     Mudit   21
# C   Praveen   23
# D    Anisha   20
# E    Kumkum   21
# F      Ravi   25
# G     Meena   19
# H     Nisha   26
# G     Rahul   28

# %%
df[['Id','Name', 'Gender', "Age"]]
# Out:
#     Id      Name  Gender  Age
# A  101  Virendra    Male   22
# B  102     Mudit    Male   21
# C  103   Praveen    Male   23
# D  104    Anisha  Female   20
# E  105    Kumkum  Female   21
# F  106      Ravi    Male   25
# G  107     Meena  Female   19
# H  108     Nisha  Female   26
# G  109     Rahul    Male   28

# %%
df.head()
# Out:
#     Id      Name            Branch  Age  Gender              Email
# A  101  Virendra  Computer Science   22    Male     Viru@gmail.com
# B  102     Mudit      Data Science   21    Male    mudit@gmail.com
# C  103   Praveen            Design   23    Male  praveen@gmail.com
# D  104    Anisha          Nurshing   20  Female   anisha@gmail.com
# E  105    Kumkum          Nurshing   21  Female   kumkum@gmail.com

# %%
df.tail()
# Out:
#     Id    Name            Branch  Age  Gender             Email
# E  105  Kumkum          Nurshing   21  Female  kumkum@gmail.com
# F  106    Ravi  Computer Science   25    Male    ravi@gmail.com
# G  107   Meena    Cyber Security   19  Female   meena@gmail.com
# H  108   Nisha            Design   26  Female   nisha@gmail.com
# G  109   Rahul  Machine Learning   28    Male   rahul@gmail.com

# %%
df.head(3)
# Out:
#     Id      Name            Branch  Age Gender              Email
# A  101  Virendra  Computer Science   22   Male     Viru@gmail.com
# B  102     Mudit      Data Science   21   Male    mudit@gmail.com
# C  103   Praveen            Design   23   Male  praveen@gmail.com

# %%
df.tail(2)
# Out:
#     Id   Name            Branch  Age  Gender            Email
# H  108  Nisha            Design   26  Female  nisha@gmail.com
# G  109  Rahul  Machine Learning   28    Male  rahul@gmail.com

# %%
df.dtypes
# Out:
# Id         int64
# Name      object
# Branch    object
# Age        int64
# Gender    object
# Email     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'Branch', 'Age', 'Gender', 'Email'], dtype='object')

# %%
list(df.columns
     )
# Out:
# ['Id', 'Name', 'Branch', 'Age', 'Gender', 'Email']

# %%
df
# Out:
#     Id      Name            Branch  Age  Gender              Email
# A  101  Virendra  Computer Science   22    Male     Viru@gmail.com
# B  102     Mudit      Data Science   21    Male    mudit@gmail.com
# C  103   Praveen            Design   23    Male  praveen@gmail.com
# D  104    Anisha          Nurshing   20  Female   anisha@gmail.com
# E  105    Kumkum          Nurshing   21  Female   kumkum@gmail.com
# F  106      Ravi  Computer Science   25    Male     ravi@gmail.com
# G  107     Meena    Cyber Security   19  Female    meena@gmail.com
# H  108     Nisha            Design   26  Female    nisha@gmail.com
# G  109     Rahul  Machine Learning   28    Male    rahul@gmail.com
