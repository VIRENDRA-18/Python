# %%
# Function

def test () :
    print("Hello Viru")
test()
# Out:
# Hello Viru

# %%
def Greeting () :
    print("Good Morning Viru")
    
Greeting ()
# Out:
# Good Morning Viru

# %%
Greeting()
# Out:
# Good Morning Viru

# %%
Greeting () + "And Riya"
# Out:
# Good Morning Viru
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2657034355.py in <cell line: 0>()
# ----> 1 Greeting () + "And Riya"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
# agar string ko bhi add krna hai to kese kerege

def Hello () :
    return "Hello Rahul"
Hello ()
# Out:
# 'Hello Rahul'

# %%
Hello () + " Ruchi"
# Out:
# 'Hello Rahul Ruchi'

# %%
def test1 () :
    return "viru", 23, 34, 23.8, [1,2,34,],  (2,4,7,8), {"key" : 1, "key2" : 2}

# %%
test1()
# Out:
# ('viru', 23, 34, 23.8, [1, 2, 34], (2, 4, 7, 8), {'key': 1, 'key2': 2})

# %%
a,b,c,d,e,f,g = test1()

# %%
a
# Out:
# 'viru'

# %%
b
# Out:
# 23

# %%
c,d
# Out:
# (34, 23.8)

# %%
e,f
# Out:
# ([1, 2, 34], (2, 4, 7, 8))

# %%
g
# Out:
# {'key': 1, 'key2': 2}

# %%
def test2 () :
    return 8 + 14 /6

# %%
test2()
# Out:
# 10.333333333333334

# %%
def test3 (a,b,c) : 
    d = a + b /c
    return d

# %%
test3(8,14,6)
# Out:
# 10.333333333333334

# %%
list = [1,2,3,4, "virendra", "Rishika", [2,4,6,8]]
list
# Out:
# [1, 2, 3, 4, 'virendra', 'Rishika', [2, 4, 6, 8]]

# %%
l1 = []
for i in list : 
    if type(i) == int or type(i) == float :
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test4 (list) :
    l1 = []
    for i in list : 
       if type(i) == int or type(i) == float :
         l1.append(i)
    return l1

# %%
test4(list)
# Out:
# [1, 2, 3, 4]

# %%
def test5(a) :
    list = []
    for i in a :
        if type(i) == list :
            for j in i :
                list.append(j)
        else :
            if type(i) == int or type(i) == float :
                list.append(i)
    return list

# %%
test5(list)
# Out:
# [1, 2, 3, 4]

# %%
list
# Out:
# [1, 2, 3, 4, 'virendra', 'Rishika', [2, 4, 6, 8]]

# %%
# *args

def Hello (*args) :
    return args

# %%
type(Hello())
# Out:
# tuple

# %%
Hello(2,3,45)
# Out:
# (2, 3, 45)

# %%
Hello(1,2,3,"Python", "Java", [1,3,5,7], {"key1" : 1, "key2" : 2})
# Out:
# (1, 2, 3, 'Python', 'Java', [1, 3, 5, 7], {'key1': 1, 'key2': 2})

# %%
def Hello1(*args,a):
    
    return args,a

# %%
Hello1(1,23,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2427405384.py in <cell line: 0>()
# ----> 1 Hello1(1,23,4)
#
# TypeError: Hello1() missing 1 required keyword-only argument: 'a'

# %%
Hello1(2,3,4,54, a = 23,22,54 )
# Out:
#   File "/tmp/ipython-input-1864617362.py", line 1
#     Hello1(2,3,4,54, a = 23,22,54 )
#                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
Hello1(2,3,4,54, a = 23 )
# only 1 hi value lega dusra argument
# Out:
# ((2, 3, 4, 54), 23)

# %%
def hello (c,d, a = 90, b=30) :
    return a,b,c,d

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2674044599.py in <cell line: 0>()
# ----> 1 hello()
#
# TypeError: hello() missing 2 required positional arguments: 'c' and 'd'

# %%
hello(20,10)
# Out:
# (90, 30, 20, 10)

# %%
hello(20,10, a=778787)
# Out:
# (778787, 30, 20, 10)

# %%
def test(**kwargs) :
    return kwargs

# %%
test()
# Out:
# {}

# %%
type(test())
# Out:
# dict

# %%
test(a=20, b="ram", c=67.5, d=[78,45,23])
# Out:
# {'a': 20, 'b': 'ram', 'c': 67.5, 'd': [78, 45, 23]}
