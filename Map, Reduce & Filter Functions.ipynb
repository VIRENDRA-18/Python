# %%
l = [2,4,6,8,9]

# %%
def test(l) :
    l1=[]
    for i in l :
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [4, 16, 36, 64, 81]

# %%
def sq(x) :
    return x**2

# %%
list(map(sq,l))
# Out:
# [4, 16, 36, 64, 81]

# %%
map(lambda x : x**2, l)

# %%
list(map(lambda x : x**2, l))
# Out:
# [4, 16, 36, 64, 81]

# %%
l = [1,2,3,4,5]
l1 = [6,7,8,9,10]

list(map(lambda x,y : x + y, l , l1))
# Out:
# [7, 9, 11, 13, 15]

# %%
# ab external function daal ke dekhte hai
def add(x,y):
    return x + y

# %%
list(map(add, l,l1))
# Out:
# [7, 9, 11, 13, 15]

# %%
str = "virendra"

# %%
list(map(lambda str : str.upper(), str))
# Out:
# ['V', 'I', 'R', 'E', 'N', 'D', 'R', 'A']

# %%
#Reduce function
from functools import reduce
l = [1,2,3,3,4,5]
reduce(lambda x , y : x + y , l)
# Out:
# 18

# %%
reduce(lambda x , y ,z: x + y + z , l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 reduce(lambda x , y ,z: x + y + z , l)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
reduce(lambda x, y : x + y, [1])
# Out:
# 1

# %%
l
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
# max number
reduce(lambda x,y : x if x > y else y, l)
# Out:
# 5

# %%
 l
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
# filter function
list(filter(lambda x : x % 2 == 0, l))
# Out:
# [2, 4]

# %%
# filter function
list(filter(lambda x : x % 2 != 0, l))
# Out:
# [1, 3, 3, 5]

# %%
l1 = [ -3,-4,6,9,-7,8,-1]
l1
# Out:
# [-3, -4, 6, 9, -7, 8, -1]

# %%
#give the negative number
list(filter(lambda x : x<0, l1))
# Out:
# [-3, -4, -7, -1]

# %%
list(filter(lambda x : x>0, l1))
# Out:
# [6, 9, 8]

# %%
l2 = ["virendra", "ram", "mudit", "ranveer", "sitaram", "anshul"]
l2
# Out:
# ['virendra', 'ram', 'mudit', 'ranveer', 'sitaram', 'anshul']

# %%
list(filter(lambda x : len(x)>6, l2))
# Out:
# ['virendra', 'ranveer', 'sitaram']

# %%
list(filter(lambda x : len(x)<6, l2))
# Out:
# ['ram', 'mudit']
