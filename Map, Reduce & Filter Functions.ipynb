# %%
l = [2,4,6,8,9]

# %%
def test(l) :
    l1=[]
    for i in l :
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [4, 16, 36, 64, 81]

# %%
def sq(x) :
    return x**2

# %%
list(map(sq,l))
# Out:
# [4, 16, 36, 64, 81]

# %%
map(lambda x : x**2, l)

# %%
list(map(lambda x : x**2, l))
# Out:
# [4, 16, 36, 64, 81]
