# %%
l = [23, 15, 656, "Virendra", True, 7 + 8j, 12.3, 45.67]
print(l)
# Out:
# [23, 15, 656, 'Virendra', True, (7+8j), 12.3, 45.67]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 23

# %%
l[5]
# Out:
# (7+8j)

# %%
l[0:7]
# Out:
# [23, 15, 656, 'Virendra', True, (7+8j), 12.3]

# %%
l
# Out:
# [23, 15, 656, 'Virendra', True, (7+8j), 12.3, 45.67]

# %%
l[7]
# Out:
# 45.67

# %%
l[-1]
# Out:
# 45.67

# %%
l[-8]
# Out:
# 23

# %%
l[-1]
# Out:
# 45.67

# %%
l[::-1]
# Out:
# [45.67, 12.3, (7+8j), True, 'Virendra', 656, 15, 23]

# %%
l[3:-1]
# Out:
# ['Virendra', True, (7+8j), 12.3]

# %%
l[2:8:2]
# Out:
# [656, True, 12.3]

# %%
l
# Out:
# [23, 15, 656, 'Virendra', True, (7+8j), 12.3, 45.67]

# %%
s1 = "virendra"
s1
# Out:
# 'virendra'

# %%
l + s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 l + s1
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 list(s1)
#
# TypeError: 'list' object is not callable

# %%
s1
# Out:
# 'virendra'

# %%
s = "Python Developer"
print(s)
# Out:
# Python Developer

# %%
lst = list(s)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 lst = list(s)
#       2 print(lst)
#
# TypeError: 'list' object is not callable

# %%
s = "Python Developer"
s
# Out:
# 'Python Developer'

# %%
list(s)
# Out:
# ['P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'D',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
#  'e',
#  'r']

# %%
l = [23, 45, 'VIRENSDR', 45.67, True, 34 + 78j]
l
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j)]

# %%
l + list(s)
# Out:
# [23,
#  45,
#  'VIRENSDR',
#  45.67,
#  True,
#  (34+78j),
#  'P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'D',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
#  'e',
#  'r']

# %%
l
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j)]

# %%
l[2]
# Out:
# 'VIRENSDR'

# %%
l[2][0:3]
# Out:
# 'VIR'

# %%
l[4]
# Out:
# True

# %%
l[4][0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l[4][0:3]
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[4])
# Out:
# 'True'

# %%
str(l[4][0:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 str(l[4][0:4])
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[4])[0:4]
# Out:
# 'True'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j)]

# %%
l1 = [34,56,32]
l1
# Out:
# [34, 56, 32]

# %%
l + l1
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j), 34, 56, 32]

# %%
len(l1)
# Out:
# 3

# %%
len(l)
# Out:
# 6

# %%
len(l + l1)
# Out:
# 9

# %%
l2 = [12,34]
l2
# Out:
# [12, 34]

# %%
len(l2)
# Out:
# 2

# %%
l1.append[455]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l1.append[455]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
l1.append(455)

# %%
l1
# Out:
# [34, 56, 32, 455]

# %%
l1
# Out:
# [34, 56, 32, 455]

# %%
l
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j)]

# %%
l.append(l1)

# %%
l
# Out:
# [23, 45, 'VIRENSDR', 45.67, True, (34+78j), [34, 56, 32, 455]]

# %%
l1
# Out:
# [34, 56, 32, 455]

# %%
l1.extend(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 l1.extend(3)
#
# TypeError: 'int' object is not iterable

# %%
l1.extend("mudit")

# %%
l1
# Out:
# [34, 56, 32, 455, 'm', 'u', 'd', 'i', 't']

# %%
l1.extend([222,333])

# %%
l1
# Out:
# [34, 56, 32, 455, 'm', 'u', 'd', 'i', 't', 222, 333]

# %%
l1
# Out:
# [34, 56, 32, 455, 'm', 'u', 'd', 'i', 't', 222, 333]

# %%
l1.insert(0,"VIRU")

# %%
l1
# Out:
# ['VIRU', 34, 56, 32, 455, 'm', 'u', 'd', 'i', 't', 222, 333]

# %%
l1.insert(1,[2,4,6])

# %%
l1
# Out:
# ['VIRU', [2, 4, 6], 34, 56, 32, 455, 'm', 'u', 'd', 'i', 't', 222, 333]

# %%
len(l1)
# Out:
# 13

# %%
list = [12, 65, 78, True, "Anisha", 61.9, False, "Anshika", 78, 6 + 2j]
print(list)
# Out:
# [12, 65, 78, True, 'Anisha', 61.9, False, 'Anshika', 78, (6+2j)]

# %%
list.pop()
# Out:
# (6+2j)

# %%
list
# Out:
# [12, 65, 78, True, 'Anisha', 61.9, False, 'Anshika', 78]

# %%
list.pop(3)
# Out:
# True

# %%
list.pop(7)
# Out:
# 78

# %%
list
# Out:
# [12, 65, 78, 'Anisha', 61.9, False, 'Anshika']

# %%
list.pop(90)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 list.pop(90)
#
# IndexError: pop index out of range

# %%
list
# Out:
# [12, 65, 78, 'Anisha', 61.9, False, 'Anshika']

# %%
list.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 list.remove()
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
list.remove(3list/)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 list.remove(3)
#
# ValueError: list.remove(x): x not in list

# %%
list.remove(65)

# %%
list
# Out:
# [12, 78, 'Anisha', 61.9, False, 'Anshika']

# %%
list.remove("Anisha")

# %%
list
# Out:
# [12, 78, 61.9, False, 'Anshika']

# %%
list.append([2,3,4,5])

# %%
list
# Out:
# [12, 78, 61.9, False, 'Anshika', [2, 3, 4, 5]]

# %%
list[5]
# Out:
# [2, 3, 4, 5]

# %%
list[5].remove(4)

# %%
list
# Out:
# [12, 78, 61.9, False, 'Anshika', [2, 3, 5]]

# %%
list[4]
# Out:
# 'Anshika'

# %%
list[4].remove(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 list[4].remove(1)
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
l1
# Out:
# ['VIRU', [2, 4, 6], 34, 56, 32, 455, 'm', 'u', 'd', 'i', 't', 222, 333]

# %%
list
# Out:
# [12, 78, 61.9, False, 'Anshika', [2, 3, 5]]

# %%
list[::-1]
# Out:
# [[2, 3, 5], 'Anshika', False, 61.9, 78, 12]

# %%
list.reverse()

# %%
list
# Out:
# [[2, 3, 5], 'Anshika', False, 61.9, 78, 12]

# %%
list.reverse()

# %%
list
# Out:
# [12, 78, 61.9, False, 'Anshika', [2, 3, 5]]

# %%
list.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 list.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
list2 = [45, 67, 89,0, 12,4,6,7,213,46,78,8]
list2
# Out:
# [45, 67, 89, 0, 12, 4, 6, 7, 213, 46, 78, 8]

# %%
list2.sort()

# %%
list2
# Out:
# [0, 4, 6, 7, 8, 12, 45, 46, 67, 78, 89, 213]

# %%
len(list2)
# Out:
# 12

# %%
list2.sort(reverse=True)

# %%
list2
# Out:
# [213, 89, 78, 67, 46, 45, 12, 8, 7, 6, 4, 0]

# %%
list3 = ["viru", "mudit","anshul","praveen", "anisha","zeeshan"]
list3
# Out:
# ['viru', 'mudit', 'anshul', 'praveen', 'anisha', 'zeeshan']

# %%
list3.sort()

# %%
list3
# Out:
# ['anisha', 'anshul', 'mudit', 'praveen', 'viru', 'zeeshan']

# %%
list3.sort(reverse=True)

# %%
list3
# Out:
# ['zeeshan', 'viru', 'praveen', 'mudit', 'anshul', 'anisha']

# %%
list3.index("viru")
# Out:
# 1

# %%
list3.index("praveen")
# Out:
# 2

# %%
list3.index("anshul")
# Out:
# 4

# %%
list3.count("anisha")
# Out:
# 1

# %%
list3.count('a')
# Out:
# 0

# %%
str = "raviii"
str
# Out:
# 'raviii'

# %%
str.count('v')
# Out:
# 1

# %%
str.count('ravi')
# Out:
# 1

# %%
str.count('i')
# Out:
# 3

# %%
list3
# Out:
# ['zeeshan', 'viru', 'praveen', 'mudit', 'anshul', 'anisha']

# %%
list3.count('e')
# Out:
# 0

# %%
list3.count('praveen')
# Out:
# 1

# %%
str = "virendra"
str
# Out:
# 'virendra'

# %%
str[1]
# Out:
# 'i'

# %%
str[1] = "e"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 str[1] = "e"
#
# TypeError: 'str' object does not support item assignment

# %%
list4 = [23, 45,78,90]
list4
# Out:
# [23, 45, 78, 90]

# %%
list4[2]
# Out:
# 78

# %%
list4[2] = 65

# %%
list4
# Out:
# [23, 45, 65, 90]

# %%
str
# Out:
# 'virendra'

# %%
str.replace("i", "ee")
# Out:
# 'veerendra'

# %%
str
# Out:
# 'virendra'

# %%
t = (2,3,4,5, True, 7 + 9j, 34.6, "pinku", 45.9, 788, False)
print(tuple)
# Out:
# (2, 3, 4, 5, True, (7+9j), 34.6, 'pinku', 45.9, 788, False)

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 11

# %%
t[3]
# Out:
# 5

# %%
t
# Out:
# (2, 3, 4, 5, True, (7+9j), 34.6, 'pinku', 45.9, 788, False)

# %%
t[7]
# Out:
# 'pinku'

# %%
t[3:7]
# Out:
# (5, True, (7+9j), 34.6)

# %%
t[::-1]
# Out:
# (False, 788, 45.9, 'pinku', 34.6, (7+9j), True, 5, 4, 3, 2)

# %%
t
# Out:
# (2, 3, 4, 5, True, (7+9j), 34.6, 'pinku', 45.9, 788, False)

# %%
t[2]
# Out:
# 4

# %%
t[2] = "rani"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 t[2] = "rani"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(4)
# Out:
# 1

# %%
t
# Out:
# (2, 3, 4, 5, True, (7+9j), 34.6, 'pinku', 45.9, 788, False)

# %%
t.index(True)
# Out:
# 4

# %%
list5 = [2,3,4,[3,6,7], "vidsh", 67.8]
list5
# Out:
# [2, 3, 4, [3, 6, 7], 'vidsh', 67.8]

# %%
list5.append((6,7,8))

# %%
list5
# Out:
# [2, 3, 4, [3, 6, 7], 'vidsh', 67.8, (6, 7, 8)]

# %%
t
# Out:
# (2, 3, 4, 5, True, (7+9j), 34.6, 'pinku', 45.9, 788, False)

# %%
d = {}
d
# Out:
# {}

# %%
type(d)
# Out:
# dict

# %%
len(d)
# Out:
# 0

# %%
s = {2,3,4,5,6,6}
print(s)
# Out:
# {2, 3, 4, 5, 6}

# %%
type(s)
# Out:
# set

# %%
len(s)
# Out:
# 5

# %%
s
# Out:
# {2, 3, 4, 5, 6}

# %%
s1 = {23,45,67, "virendra", "mudit", 67.7, 4 + 7j, True}
print(s1)
# Out:
# {True, 67, 67.7, 'virendra', 45, 23, (4+7j), 'mudit'}

# %%
type(s1)
# Out:
# set

# %%
s1[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 s1[3]
#
# TypeError: 'set' object is not subscriptable

# %%
s3 = {1,2,2,3,4,4,4,66,77,55,55,778,34,65}
s3
# Out:
# {1, 2, 3, 4, 34, 55, 65, 66, 77, 778}

# %%
s4 = {344,65464,896,"viru", 34,2, 52,13}
s4
# Out:
# {13, 2, 34, 344, 52, 65464, 896, 'viru'}

# %%
s4[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 s4[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s4.difference()
# Out:
# {13, 2, 34, 344, 52, 65464, 896, 'viru'}

# %%
s4.add(687898)

# %%
s4
# Out:
# {13, 2, 34, 344, 52, 65464, 687898, 896, 'viru'}

# %%
s4.remove(34)

# %%
s4
# Out:
# {13, 2, 344, 52, 65464, 687898, 896, 'viru'}

# %%
s4.pop()
# Out:
# 896

# %%
s4
# Out:
# {13, 2, 344, 52, 65464, 687898, 'viru'}

# %%
s4.pop()
# Out:
# 2

# %%
s4
# Out:
# {13, 344, 52, 65464, 687898, 'viru'}

# %%
s4.pop()
# Out:
# 13
