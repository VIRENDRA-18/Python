# %%
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
x = 5
print(x + a)
# Out:
# 15

# %%
type(a)
# Out:
# int

# %%
y = 12.5
z = 6
print(y-z)
# Out:
# 6.5

# %%
type(y-z)
# Out:
# float

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# int

# %%
a = 20
b = 7
print("the sum of a + b is :", a + b)
print("the sum of a - b is :", a - b)
print("the sum of a * b is :", a * b)
print("the sum of a / b is :", a / b)
# Out:
# the sum of a + b is : 27
# the sum of a - b is : 13
# the sum of a * b is : 140
# the sum of a / b is : 2.857142857142857

# %%
d = "VIRENDRA"
print(d)
# Out:
# VIRENDRA

# %%
Name = 'viru'
print(Name)
# Out:
# viru

# %%
type(Name)
# Out:
# str

# %%
print(d + Name)
# Out:
# VIRENDRAviru

# %%
print(d + " " + Name)
# Out:
# VIRENDRA viru

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(d)
# Out:
# str

# %%
College = 'i am virendra singh. i am "React Developer"'
print(College)
# Out:
# i am virendra singh. i am "React Developer"

# %%
type(College)
# Out:
# str

# %%
n = True
print(n)
# Out:
# True

# %%
n = 1
print(n)
# Out:
# 1

# %%
m = False
print(m)
# Out:
# False

# %%
print(n + m)
# Out:
# 1

# %%
print(n - m)
# Out:
# 1

# %%
print(m - n)
# Out:
# -1

# %%
type(print(m - n))
# Out:
# -1
# NoneType

# %%
viru = 6 + 9j
print(viru)
# Out:
# (6+9j)

# %%
type(viru)
# Out:
# complex

# %%
viru.real
# Out:
# 6.0

# %%
viru.imag
# Out:
# 9.0

# %%
ram = 4 + 7j
print(ram)
# Out:
# (4+7j)

# %%
viru + ram
# Out:
# (10+16j)

# %%
viru
# Out:
# (6+9j)

# %%
type(ram)
# Out:
# complex

# %%
a =  "virendra"
a
# Out:
# 'virendra'

# %%
a[1]
# Out:
# 'i'

# %%
a[0]
# Out:
# 'v'

# %%
a[0:4]
# Out:
# 'vire'

# %%
a
# Out:
# 'virendra'

# %%
a[0:8]
# Out:
# 'virendra'

# %%
name = "VIRENDRAsingh"
print(name)
# Out:
# VIRENDRAsingh

# %%
name[0:8]
# Out:
# 'VIRENDRA'

# %%
name[0:8:2]
# Out:
# 'VRNR'

# %%
name[-1:-8]
# Out:
# ''

# %%
name[-2:-8:1]
# Out:
# ''

# %%
s1 = "i am viru work on python development"
print(s1)
# Out:
# i am viru work on python development

# %%
len(s1)
# Out:
# 36

# %%
s1.find('v')
# Out:
# 5

# %%
s1.find('p')
# Out:
# 18

# %%
s1.find('python')
# Out:
# 18

# %%
s1.find('x')
# Out:
# -1

# %%
s1.count('v')
# Out:
# 2

# %%
s1
# Out:
# 'i am viru work on python development'

# %%
s1.count('o')
# Out:
# 4

# %%
s1.count('th')
# Out:
# 1

# %%
s1.upper()
# Out:
# 'I AM VIRU WORK ON PYTHON DEVELOPMENT'

# %%
s1.lower()
# Out:
# 'i am viru work on python development'

# %%
s1.upper()
# Out:
# 'I AM VIRU WORK ON PYTHON DEVELOPMENT'

# %%
s1.index('am')
# Out:
# 2

# %%
s1.index('ve')
# Out:
# 27

# %%
s2 = 'i am virendra and "MY NICKNAME IS VIRU"'
s2
# Out:
# 'i am virendra and "MY NICKNAME IS VIRU"'

# %%
s2.lower()
# Out:
# 'i am virendra and "my nickname is viru"'

# %%
s2.upper()
# Out:
# 'I AM VIRENDRA AND "MY NICKNAME IS VIRU"'

# %%
s2
# Out:
# 'i am virendra and "MY NICKNAME IS VIRU"'

# %%
len(s2)
# Out:
# 39

# %%
s2.title()
# Out:
# 'I Am Virendra And "My Nickname Is Viru"'

# %%
s2
# Out:
# 'i am virendra and "MY NICKNAME IS VIRU"'

# %%
s2.title()
# Out:
# 'I Am Virendra And "My Nickname Is Viru"'

# %%
s2.capitalize()
# Out:
# 'I am virendra and "my nickname is viru"'
