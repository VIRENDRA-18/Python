# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("Virendra"))
# Out:
# <class 'str'>

# %%
# how to create class in python

# %%
class test :
# Out:
#   Cell In[10], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
class test : 
    pass

# %%
a = test()

# %%
type(a)
# Out:
# __main__.test

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class pwskills :
    def welcome_msg () :
        print("Welcome to pwskills virendra")

# %%
class pwskills :
    def welcome_msg (self) :
        print("Welcome to pwskills virendra")

# %%
virendra = pwskills()

# %%
print(type(virendra))
# Out:
# <class '__main__.pwskills'>

# %%
virendra.welcome_msg()
# Out:
# Welcome to pwskills virendra

# %%
virendra = pwskills()
class pwskills :
    def welcome_msg (self) :
        print("Welcome to pwskills virendra")
virendra.welcome_msg()        
# pura ek saat bhi ashe likh sekhta hu mai class ko
# Out:
# Welcome to pwskills virendra

# %%
class pwskills1 :
    def __init__(self, phone_number, email_id, student_id) :
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id=student_id

    def return_student_deetails(self) :
        return self.student_id, self.phone_number, self.email_id

# %%
virendra = pwskills1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 virendra = pwskills1()
#
# TypeError: pwskills1.__init__() missing 3 required positional arguments: 'phone_number', 'email_id', and 'student_id'

# %%
virendra = pwskills1(8384934906, "viru0124@gmail.com", 18)

# %%
virendra.return_student_deetails()
# Out:
# (18, 8384934906, 'viru0124@gmail.com')

# %%
virendra.email_id
# Out:
# 'viru0124@gmail.com'

# %%
anshul = pwskills1(7878324507, "anshul12@gmail.com", 19)

# %%
anshul.return_student_deetails()
# Out:
# (19, 7878324507, 'anshul12@gmail.com')

# %%
anshul.phone_number
# Out:
# 7878324507

# %%
class pwskills2 :
    def __init__(self, phone_number, email_id, student_id) :
        self.phone_number1 = phone_number
        self.email_id1 = email_id
        self.student_id1 = student_id

    def return_student_deetails(self) :
        return self.student_id1, self.phone_number1, self.email_id1

# %%
vedant = pwskills2(9415378608, "vedantjoshi@gmail.com", 121)

# %%
vedant

# %%
vedant.email_id1
# Out:
# 'vedantjoshi@gmail.com'

# %%
vedant.phone_number1
# Out:
# 9415378608

# %%
vedant.return_student_deetails()
# Out:
# (121, 9415378608, 'vedantjoshi@gmail.com')

# %%
vedant.return_student_deetails()
# Out:
# (121, 9415378608, 'vedantjoshi@gmail.com')

# %%
class pwskills2 :
    def __init__(viru, phone_number, email_id, student_id) :
        viru.phone_number1 = phone_number
        viru.email_id1 = email_id
        viru.student_id1 = student_id

    def return_student_deetails(self) :
        return viru.student_id1, viru.phone_number1, viru.email_id1

# %%
virendra = pwskills2(6432746327, "veer@gmail.com", 78)

# %%
virendra.phone_number1
# Out:
# 6432746327

# %%
1/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 1/False
#
# ZeroDivisionError: division by zero

# %%
num1= 23
num2= 44
num2= 2+3j
num1= num2.imag
num2-num1
# Out:
# 3.0

# %% [markdown]
# PRACTICE

# %%
class test :
# Out:
#   Cell In[23], line 1
#     class test :
#                 ^
# _IncompleteInputError: incomplete input

# %%
class test :
 pass

# %%
class pwskills :
    def welcome_msg(self) :
        print("Welcome to pwskills")

# %%
rohan = pwskills()

# %%
rohan.welcome_msg()
# Out:
# Welcome to pwskills

# %%
Mudit = pwskills()

# %%
Mudit.welcome_msg()
# Out:
# Welcome to pwskills

# %%
class pwskills1 :
    def __init__(self, Phone_Number, Email_Id, Student_Id):
        self.Phone_Number1 = Phone_Number
        self.Email_Id1 = Email_Id
        self.Student_Id1 = Student_Id

    def return_student_detailed (self)   :
        return self.Student_Id1, self.Phone_Number1, self.Email_Id1

# %%
Virendra = pwskills1(101, 8787378787, 'viru@gmail.com')

# %%
Virendra.return_student_detailed()
# Out:
# ('viru@gmail.com', 101, 8787378787)

# %%
Virendra.Email_Id1
# Out:
# 8787378787
